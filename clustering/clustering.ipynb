# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Set random seed for reproducibility
np.random.seed(42)

# Number of data points per cluster
num_points = 50
spread = 0.5

# Generate data for cluster 1
cluster1_x = np.random.normal(loc=1.5, scale=spread, size=num_points)
cluster1_y = np.random.normal(loc=0.5, scale=spread, size=num_points)

# Generate data for cluster 2
cluster2_x = np.random.normal(loc=4, scale=spread, size=num_points)
cluster2_y = np.random.normal(loc=1.2, scale=spread, size=num_points)

# Generate data for cluster 3
cluster3_x = np.random.normal(loc=6, scale=spread, size=num_points)
cluster3_y = np.random.normal(loc=2, scale=spread, size=num_points)

# Concatenate data from all clusters
x = np.concatenate([cluster1_x, cluster2_x, cluster3_x])
y = np.concatenate([cluster1_y, cluster2_y, cluster3_y])

# %%
sns.color_palette("husl", 24)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.9699521567340649, 0.4569882390259858, 0.36385324448493633),
#  (0.903599057664843, 0.511987276335809, 0.19588350060161624),
#  (0.8087954113106306, 0.5634700050056693, 0.19502642696727285),
#  (0.7350228985632719, 0.5952719904750953, 0.1944419133847522),
#  (0.6666319352625271, 0.6197366714155128, 0.19396267878823373),
#  (0.5920891529639701, 0.6418467016378244, 0.1935069134991043),
#  (0.49382662140640926, 0.6649121332643736, 0.19300804648700284),
#  (0.3126890019504329, 0.6928754610296064, 0.1923704830330379),
#  (0.19783576093349015, 0.6955516966063037, 0.3995301037444499),
#  (0.20312757197899856, 0.6881249249803418, 0.5177618167447304),
#  (0.20703735729643502, 0.6824290013722435, 0.5885318893529169),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.21387918628643265, 0.6720135434784761, 0.693961140878689),
#  (0.21786710662428366, 0.6656671601322255, 0.7482809385065813),
# ...

# %%
# Plot the synthetic data
fig, ax = plt.subplots()
plt.scatter(cluster1_x, cluster1_y, color=sns.color_palette("hls",24)[1], alpha=.9, s=40)
plt.scatter(cluster2_x, cluster2_y, color=sns.color_palette("hls",24)[7], alpha=.9, s=40)
plt.scatter(cluster3_x, cluster3_y, color=sns.color_palette("hls",24)[15], alpha=.9, s=40)

plt.title('Synthetic Data with 3 Clusters: Labels Availables')
plt.xlabel('Petal length')
plt.ylabel('Petal width')
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.legend(labels=['Flower A', 'Flower B', 'Flower C'], loc='lower right')

plt.savefig('clustering_classes.png', dpi=500)

# %%
# Plot the synthetic data
fig, ax = plt.subplots()
plt.scatter(cluster1_x, cluster1_y, color='k', alpha=.9, s=40)
plt.scatter(cluster2_x, cluster2_y, color='k', alpha=.9, s=40)
plt.scatter(cluster3_x, cluster3_y, color='k', alpha=.9, s=40)

plt.title('Synthetic Data with 3 Clusters: Labels Not Availables')
plt.xlabel('Petal length')
plt.ylabel('Petal width')
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.savefig('clustering_no_classes.png', dpi=500)

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Generate synthetic data
X, _ = make_blobs(n_samples=300, centers=5, cluster_std=0.4, random_state=42, center_box=(-4,4))

# Apply K-means clustering
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X)

# Plot data points and cluster centroids
fig, ax = plt.subplots()
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, cmap='gist_rainbow', alpha=0.7, s=40)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='x', s=40, c='k', label='Centroids')
plt.title('K-Means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
# plt.legend()
ax.spines['top'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.spines['left'].set_visible(False)
ax.xaxis.set_ticks_position('none') 
ax.yaxis.set_ticks_position('none') 
plt.savefig('k-means_01.png', dpi=500)

# %%
# Generate synthetic data
X, _ = make_blobs(n_samples=300, centers=5, cluster_std=0.4, random_state=42, center_box=(-4,4))

# Apply K-means clustering
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
X, _ = make_blobs(n_samples=300, centers=5, cluster_std=0.4, random_state=42, center_box=(-4,4))
inertias = []
for k in list(range(2,11)):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

fig, ax = plt.subplots()
ax.plot(list(range(2,11)), inertias, linewidth=2, color=sns.color_palette("hls",24)[14], alpha=.9)
plt.title('Inertia vs. N of clusters')
plt.xlabel('N. of clusters')
plt.ylabel('Inertia')
ax.spines['top'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.spines['left'].set_visible(False)
ax.xaxis.set_ticks_position('none') 
ax.yaxis.set_ticks_position('none') 
plt.savefig('k-means_02.png', dpi=500)

# %%
from sklearn.datasets import make_moons
from sklearn.datasets import make_circles
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# %%
X, _ = make_moons(n_samples=1000, noise=0.05, random_state=42)
dbscan_1 = DBSCAN(eps=0.05, min_samples=5)
dbscan_1.fit(X)

dbscan_2 = DBSCAN(eps=0.2, min_samples=5)
dbscan_2.fit(X)
# Out:
# DBSCAN(eps=0.2)

# %%
fig, axes = plt.subplots(1,2,figsize=(16, 8))
# Plot data points and cluster assignments
axes[0].scatter(X[:, 0], X[:, 1], c=dbscan_1.labels_, cmap='viridis', alpha=0.9, s=60)
axes[0].set_title('DBSCAN Clustering\nepsilon=0.05, min_samples=5')
axes[0].spines['top'].set_visible(False)
axes[0].spines['bottom'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].spines['left'].set_visible(False)
axes[0].spines['left'].set_visible(False)
axes[0].xaxis.set_ticks_position('none') 
axes[0].yaxis.set_ticks_position('none')

axes[1].scatter(X[:, 0], X[:, 1], c=dbscan_2.labels_, cmap='viridis', alpha=0.9, s=60)
axes[1].set_title('DBSCAN Clustering\nepsilon=0.2, min_samples=5')
axes[1].spines['top'].set_visible(False)
axes[1].spines['bottom'].set_visible(False)
axes[1].spines['right'].set_visible(False)
axes[1].spines['left'].set_visible(False)
axes[1].spines['left'].set_visible(False)
axes[1].xaxis.set_ticks_position('none') 
axes[1].yaxis.set_ticks_position('none')

plt.savefig('dbscan_01.png', dpi=500)

# %%
X, _ = make_circles(n_samples=1000, noise=0.05, random_state=42, factor=.5)
dbscan_1 = DBSCAN(eps=0.05, min_samples=5)
dbscan_1.fit(X)

dbscan_2 = DBSCAN(eps=0.2, min_samples=5)
dbscan_2.fit(X)
# Out:
# DBSCAN(eps=0.2)

# %%
fig, axes = plt.subplots(1,2,figsize=(16, 8))
# Plot data points and cluster assignments
axes[0].scatter(X[:, 0], X[:, 1], c=dbscan_1.labels_, cmap='viridis', alpha=0.9, s=60)
axes[0].set_title('DBSCAN Clustering\nepsilon=0.05, min_samples=5')
axes[0].spines['top'].set_visible(False)
axes[0].spines['bottom'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].spines['left'].set_visible(False)
axes[0].spines['left'].set_visible(False)
axes[0].xaxis.set_ticks_position('none') 
axes[0].yaxis.set_ticks_position('none')

axes[1].scatter(X[:, 0], X[:, 1], c=dbscan_2.labels_, cmap='viridis', alpha=0.9, s=60)
axes[1].set_title('DBSCAN Clustering\nepsilon=0.2, min_samples=5')
axes[1].spines['top'].set_visible(False)
axes[1].spines['bottom'].set_visible(False)
axes[1].spines['right'].set_visible(False)
axes[1].spines['left'].set_visible(False)
axes[1].spines['left'].set_visible(False)
axes[1].xaxis.set_ticks_position('none') 
axes[1].yaxis.set_ticks_position('none')

plt.savefig('dbscan_02.png', dpi=500)
